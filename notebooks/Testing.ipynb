# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🧪 Model Testing Notebook\n",
    "Use this notebook to test the trained CNN phishing URL detector manually."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from tensorflow.keras.models import load_model\n",
    "import joblib\n",
    "from tensorflow.keras.preprocessing.sequence import pad_sequences\n",
    "from src.preprocessing.clean_url import clean_url\n",
    "from src.preprocessing.encode import encode_url\n",
    "from src.utils.config import MAX_LEN\n",
    "\n",
    "model = load_model('../saved_models/cnn_url_model.h5')\n",
    "tokenizer = joblib.load('../saved_models/tokenizer.pkl')\n",
    "\n",
    "print('Model Loaded Successfully!')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Test a URL Manually"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "def test_url(url):\n",
    "    cleaned = clean_url(url)\n",
    "    encoded = [tokenizer.get(ch, 0) for ch in cleaned]\n",
    "    padded = pad_sequences([encoded], maxlen=MAX_LEN)\n",
    "    prob = model.predict(padded)[0][0]\n",
    "    label = 'Phishing' if prob > 0.5 else 'Legitimate'\n",
    "    return label, prob\n",
    "\n",
    "url = input('Enter URL: ')\n",
    "label, prob = test_url(url)\n",
    "\n",
    "print(f\"Prediction: {label}\")\n",
    "print(f\"Probability: {prob:.4f}\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
